# %%
greet = "Hi there, Bitches"
print(greet)
# Out:
# Hi there, Bitches

# %%
type(greet)
# Out:
# str

# %%
num = 19.3345
num = int(num)
num = str(num)
num
# Out:
# '19'

# %%
10 // 3
# Out:
# 3

# %%
10 % 3
# Out:
# 2

# %%
for num in range(5):
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for num in range(0,10, 2):
    print(num, end= " ")
# Out:
# 0 2 4 6 8

# %%
for char in "Hello World":
    print(char, end= " ")
# Out:
# H e l l o   W o r l d

# %%
for outer_num in range(5):
    for inner_num in range (3):
        print(outer_num, inner_num, end= " ")
# Out:
# 0 0 0 1 0 2 1 0 1 1 1 2 2 0 2 1 2 2 3 0 3 1 3 2 4 0 4 1 4 2

# %%
num = 0
while num < 5:
    num += 1
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
num = 0
for num in range(10):
    if num == 5:
        continue
    print("Number is " + str(num))
print("Out of loop")
# Out:
# Number is 0
# Number is 1
# Number is 2
# Number is 3
# Number is 4
# Number is 6
# Number is 7
# Number is 8
# Number is 9
# Out of loop

# %%
def add(a, b):
    return a + b

# %%
def multiply(a, b):
    return a * b

# %%
def add_and_multiply(a, b):
    print(add(a, b) * multiply(a, b))

# %%
add_and_multiply(1, 2)
# Out:
# 6

# %%
def welcome(name = "Eliano"):
    return "Welcome " + name

# %%
welcome("David")
# Out:
# 'Welcome David'
